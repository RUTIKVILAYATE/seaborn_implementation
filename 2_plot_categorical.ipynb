# %%
# Categorical Scatterplots
# from seaborn import fivethirtyeight
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x = "day", y = "tip", kind = "strip", jitter = 0, data = tips )

# %%
sns.catplot(x = "day", y = "tip", kind = "swarm", data=tips)
# Out:
# c:\Users\Rutik Vilayate\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x = "day", y = "tip", kind = "swarm",hue = "sex" ,data=tips)
# Out:
# c:\Users\Rutik Vilayate\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x = "day", y = "tip", data = tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>
